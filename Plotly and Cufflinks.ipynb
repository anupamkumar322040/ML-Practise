# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
from plotly import __version__

# %%
print(__version__)
# Out:
# 3.10.0

# %%
import cufflinks as cf

# %%
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot

# %%
init_notebook_mode(connected=True) #connects notebook to js library
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()#sets cufflinks in offline mode
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.DataFrame(np.random.randn(100,4),columns='A B C D'.split())

# %%
df.head()
# Out:
#           A         B         C         D
# 0 -1.181992  1.064940 -0.178455  1.139839
# 1  0.015511 -1.437429 -0.588449 -1.277694
# 2  1.292704  1.292680 -0.068373  0.863349
# 3  0.636228  1.087218 -0.234666  1.869808
# 4  0.847147 -0.441061  0.493006  0.353407

# %%
df2 = pd.DataFrame({'Category':['A','B','C'],'Value':[20,32,24]})

# %%
df2
# Out:
#   Category  Value
# 0        A     20
# 1        B     32
# 2        C     24

# %%
df.plot()

# %%
df.iplot()
# Out:
# <div>
#
#
#             <div id="2ae7930e-c38e-493a-9f26-f057ba88d1d9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("2ae7930e-c38e-493a-9f26-f057ba88d1d9")) {
#                     Plotly.newPlot(
#                         '2ae7930e-c38e-493a-9f26-f057ba88d1d9',
# ...

# %%
df.iplot(kind='scatter',x='A',y='B') #pass mode to avoid these lines drawing
# Out:
# <div>
#
#
#             <div id="778e5e02-f190-4c8e-9329-dd805307aa98" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("778e5e02-f190-4c8e-9329-dd805307aa98")) {
#                     Plotly.newPlot(
#                         '778e5e02-f190-4c8e-9329-dd805307aa98',
# ...

# %%
df.iplot(kind='scatter',x='A',y='B',mode='markers',size=20)
# Out:
# <div>
#
#
#             <div id="db91d346-b45f-4e08-9540-919e88e36424" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("db91d346-b45f-4e08-9540-919e88e36424")) {
#                     Plotly.newPlot(
#                         'db91d346-b45f-4e08-9540-919e88e36424',
# ...

# %%
df2.iplot(kind='bar',x='Category',y='Value')
# Out:
# <div>
#
#
#             <div id="496a45e8-c9c6-4e3d-9f13-cdfb171ef6f1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("496a45e8-c9c6-4e3d-9f13-cdfb171ef6f1")) {
#                     Plotly.newPlot(
#                         '496a45e8-c9c6-4e3d-9f13-cdfb171ef6f1',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "Value", "orientation": "v", "text": "", "type": "bar", "uid": "fd65f93e-a75b-4816-9614-eb0ee0d34bb6", "x": ["A", "B", "C"], "y": [20, 32, 24]}],
# ...

# %%
df.sum().iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="94bab2c3-bc1d-4d73-be61-83f6fd71d3af" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("94bab2c3-bc1d-4d73-be61-83f6fd71d3af")) {
#                     Plotly.newPlot(
#                         '94bab2c3-bc1d-4d73-be61-83f6fd71d3af',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "None", "orientation": "v", "text": "", "type": "bar", "uid": "3c814107-d5e5-417e-ab68-b0856afb11fd", "x": ["A", "B", "C", "D"], "y": [-2.8105226145279167, 5.7249213679915005, 15.794763637284763, 6.487843298630881]}],
# ...

# %%
df.iplot(kind='box')
# Out:
# <div>
#
#
#             <div id="ec9ae21d-790e-4269-a6ed-0261d13ca341" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ec9ae21d-790e-4269-a6ed-0261d13ca341")) {
#                     Plotly.newPlot(
#                         'ec9ae21d-790e-4269-a6ed-0261d13ca341',
# ...

# %%
df3 = pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10], 'z':[100,200,300,400,200]})

# %%
df3
# Out:
#    x   y    z
# 0  1  10  100
# 1  2  20  200
# 2  3  30  300
# 3  4  20  400
# 4  5  10  200

# %%
df3.iplot(kind='surface')
# Out:
# <div>
#
#
#             <div id="e34480f9-5293-472d-a26a-0cf655e0c0fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("e34480f9-5293-472d-a26a-0cf655e0c0fc")) {
#                     Plotly.newPlot(
#                         'e34480f9-5293-472d-a26a-0cf655e0c0fc',
# ...

# %%
df4 = pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10], 'z':[5,4,3,2,1]})

# %%
df4.iplot(kind='surface',colorscale='rdylbu')
# Out:
# <div>
#
#
#             <div id="fb70b9e1-5216-4c77-a230-ea8227f71de4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("fb70b9e1-5216-4c77-a230-ea8227f71de4")) {
#                     Plotly.newPlot(
#                         'fb70b9e1-5216-4c77-a230-ea8227f71de4',
# ...

# %%
df['A'].iplot(kind='hist')
# Out:
# <div>
#
#
#             <div id="0433c990-6e46-40df-9e14-46398b69e363" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("0433c990-6e46-40df-9e14-46398b69e363")) {
#                     Plotly.newPlot(
#                         '0433c990-6e46-40df-9e14-46398b69e363',
# ...

# %%
df.iplot(kind='hist')
# Out:
# <div>
#
#
#             <div id="78ecf66b-4386-4ad9-8224-6bc01b39cb55" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("78ecf66b-4386-4ad9-8224-6bc01b39cb55")) {
#                     Plotly.newPlot(
#                         '78ecf66b-4386-4ad9-8224-6bc01b39cb55',
# ...

# %%
df[['A','B']].iplot(kind='spread')
# Out:
# <div>
#
#
#             <div id="332ed217-87b5-46f0-815e-647b5da8c317" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("332ed217-87b5-46f0-815e-647b5da8c317")) {
#                     Plotly.newPlot(
#                         '332ed217-87b5-46f0-815e-647b5da8c317',
# ...

# %%
df.iplot(kind='bubble',x='A',y='B',size='C')
# Out:
# <div>
#
#
#             <div id="b4069199-fab5-4e5e-a413-55fe4e8a44a7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("b4069199-fab5-4e5e-a413-55fe4e8a44a7")) {
#                     Plotly.newPlot(
#                         'b4069199-fab5-4e5e-a413-55fe4e8a44a7',
# ...

# %%
df.scatter_matrix() #this is bug on 12/06/2019 latest release otherwise it'll show the pairplot like plots for each numerical coloumn pair
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-c8ca37fa1904> in <module>
# ----> 1 df.scatter_matrix() #this is bug on 12/06/2019 latest release otherwise it'll show the pairplot like plots for each numerical coloumn pair
#
# ~\Anaconda3\lib\site-packages\cufflinks\plotlytools.py in _scatter_matrix(self, theme, bins, color, size, asFigure, **iplot_kwargs)
#    1277                         Keyword arguments to pass through to `iplot`
#    1278 	"""
# -> 1279         sm=tools.scatter_matrix(self,theme=theme,bins=bins,color=color,size=size)
#    1280         if asFigure:
#    1281                 return sm
#
# ~\Anaconda3\lib\site-packages\cufflinks\tools.py in scatter_matrix(df, theme, bins, color, size)
#    1017         layout['yaxis'].update(showgrid=False)
# ...
